# %%
list = [20,'string',10.20]

# %%
print(list)
# Out:
# [20, 'string', 10.2]

# %%
list.append[20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\AJITAN~1\AppData\Local\Temp/ipykernel_5808/1138570133.py in <module>
# ----> 1 list.append[20]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
list.append(10)

# %%
print(list)
# Out:
# [20, 'string', 10.2, 10, 10]

# %%
'day' + str(1)
# Out:
# 'day1'

# %%
name = 'edureka'

# %%
name[2]
# Out:
# 'u'

# %%
name[2:5]
# Out:
# 'ure'

# %% [markdown]
# name[2:8]

# %%
name[2:9]
# Out:
# 'ureka'

# %%
name[2:10]
# Out:
# 'ureka'

# %%
name.upper()
# Out:
# 'EDUREKA'

# %%
name.lower()
# Out:
# 'edureka'

# %%
mylist = [10,'ajit',10.2,'raj']

# %%
print(mylist)
# Out:
# [10, 'ajit', 10.2, 'raj']

# %%
mylist.append(10)

# %%
print(mylist)
# Out:
# [10, 'ajit', 10.2, 'raj', 10]

# %%
mylist[2:5]
# Out:
# [10.2, 'raj', 10]

# %%
mylist[2] = 35

# %%
print(mylist)
# Out:
# [10, 'ajit', 35, 'raj', 10]

# %%
mylist.insert(2,100)

# %%
print(mylist)
# Out:
# [10, 'ajit', 100, 100, 35, 'raj', 10]

# %%
mylist.reverse()

# %%
print(mylist)
# Out:
# [10, 'ajit', 100, 100, 35, 'raj', 10]

# %%
mylist
# Out:
# [10, 'ajit', 100, 100, 35, 'raj', 10]

# %%
mylist.reverse()

# %%
mylist
# Out:
# [10, 'raj', 35, 100, 100, 'ajit', 10]

# %%
course = {1 : 'python',
         2 : 'data science',
         'third' : 'machine'}

# %%
course
# Out:
# {1: 'python', 2: 'data science', 'third': 'machine'}

# %%
course[2]
# Out:
# 'data science'

# %%
course['third'] = 'hadoop'

# %%
course
# Out:
# {1: 'python', 2: 'data science', 'third': 'hadoop'}

# %%
course['four'] = 'machine'

# %%
course
# Out:
# {1: 'python', 2: 'data science', 'third': 'hadoop', 'four': 'machine'}

# %%
animals = (10,20,20,'tiger','lion','tiger')

# %%
animals[2]
# Out:
# 20

# %%
animals.count('tiger')
# Out:
# 2

# %%
first_string = 'python'
second_string = ' is a powerful'
third_string = ' language'

# %%
print(first_string + second_string + third_string
# Out:
# python is a powerful language
